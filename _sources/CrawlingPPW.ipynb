# %% [markdown]
# # Crawling PTA & Berita

# %% [markdown]
# ### Library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re, sys, time

# %% [markdown]
# ## 1. Crawling PTA

# %%
BASE_URL = "https://pta.trunojoyo.ac.id/c_search/byprod"

# %% [markdown]
# ### Fungsi

# %%
def get_max_page(prodi_id):
    url = f"{BASE_URL}/{prodi_id}/1"
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")

    # Cari tombol >> (last page)
    last_page = soup.select_one('ol.pagination a:contains("»")')
    if last_page and "href" in last_page.attrs:
        href = last_page["href"]
        # Pecah URL -> ambil angka terakhir
        max_page = int(href.split("/")[-1])
        return max_page

    # fallback kalau pagination tidak ada
    return 1

# %%
# Contoh pemakaian
print(get_max_page(10))
# Out:
# 172
# /usr/local/lib/python3.12/dist-packages/soupsieve/css_parser.py:876: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028

# %%
def print_progress(prodi_id, prodi, current_page, total_pages):
    percent = (current_page / total_pages) * 100
    bar_length = 20
    filled_length = int(bar_length * current_page // total_pages)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    sys.stdout.write(f'\r[{prodi_id}] {prodi} - Page {current_page}/{total_pages} [{bar}] {percent:.2f}%')
    sys.stdout.flush()
    if current_page == total_pages:
        sys.stdout.write('\n')

# %% [markdown]
# ### Fungsi Crawling Semua Data PTA

# %%
def pta_all():
    start_time = time.time()

    data = {
        "id": [],
        "penulis": [],
        "judul": [],
        "abstrak_id": [],
        "abstrak_en": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "prodi": []
    }

    total_prodi = 3
    total_pages = 0
    max_pages_dict = {}

    # hitung total halaman (untuk tiap prodi)
    for i in range(1, total_prodi + 1):
        max_page = get_max_page(i)
        max_pages_dict[i] = max_page
        total_pages += max_page

    for i in range(1, total_prodi + 1):
        max_page = max_pages_dict[i]
        for j in range(1, max_page + 1):
            url = f"{BASE_URL}/{i}/{j}"
            r = requests.get(url)
            soup = BeautifulSoup(r.content, "html.parser")
            jurnals = soup.select('li[data-cat="#luxury"]')

            isii = soup.select_one('div#begin')
            if not isii:
                continue
            prodi_full = isii.select_one('h2').text.strip()
            prodi = prodi_full.replace("Journal Jurusan ", "")

            for jurnal in jurnals:
                link_keluar = jurnal.select_one('a.gray.button')['href']

                # ambil ID dari link PTA (angka terakhir di URL)
                id_match = re.search(r"/detail/(\d+)", link_keluar)
                pta_id = id_match.group(1) if id_match else None

                response = requests.get(link_keluar)
                soup1 = BeautifulSoup(response.content, "html.parser")
                isi = soup1.select_one('div#content_journal')

                judul = isi.select_one('a.title').text.strip()
                penulis = isi.select_one('span:contains("Penulis")').text.split(' : ')[1]
                pembimbing_pertama = isi.select_one('span:contains("Dosen Pembimbing I")').text.split(' : ')[1]
                pembimbing_kedua = isi.select_one('span:contains("Dosen Pembimbing II")').text.split(' :')[1]

                paragraf = isi.select('p[align="justify"]')
                abstrak_id = paragraf[0].get_text(strip=True) if len(paragraf) > 0 else "N/A"
                abstrak_en = paragraf[1].get_text(strip=True) if len(paragraf) > 1 else "N/A"

                data["id"].append(pta_id)
                data["penulis"].append(penulis)
                data["judul"].append(judul)
                data["abstrak_id"].append(abstrak_id)
                data["abstrak_en"].append(abstrak_en)
                data["pembimbing_pertama"].append(pembimbing_pertama)
                data["pembimbing_kedua"].append(pembimbing_kedua)
                data["prodi"].append(prodi)

            # update progress bar per prodi
            print_progress(i, prodi, j, max_page)

        sys.stdout.write("\n")  # pindah baris setelah 1 prodi selesai

    # simpan ke CSV
    df = pd.DataFrame(data)
    df.to_csv("pta_all.csv", index=False, encoding="utf-8-sig")

    # hitung durasi
    end_time = time.time()
    elapsed = int(end_time - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    # summary
    print("\n✅ Seluruh data berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱️ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

# %%
pta_all()
# Out:
# [1] Ilmu Hukum - Page 284/284 [████████████████████] 100.00%
#
# [2] Teknologi Industri Pertanian - Page 114/114 [████████████████████] 100.00%
#
# [3] Agribisnis - Page 110/110 [████████████████████] 100.00%
#
#
# ✅ Seluruh data berhasil dikumpulkan!
# 📊 Total entri: 2532
# ⏱️ Waktu eksekusi: 3 jam 48 menit 34 detik
#                 id                           penulis  \
# 0     080111100012               Dyah Ayu Citra Seza
# 1     080111100002                  Maulina Nurlaily
# 2     070111100060               Moh. Samsul Hidayat
# 3     090111100077  TOMMY ADITYA PARLINDUNGAN MARBUN
# 4     070111200007                RICA YENA IMADHORA
# ...            ...                               ...
# 2527  160321100007                     Meilinda Sari
# 2528  160321100064        Chilyatun Nafisah Oktavina
# 2529  160321100035                 I'ANATUS SHOFIYAH
# 2530  160321100038                  Lilis Nur Azizah
# 2531  160321100052                            farida
#
#                                                   judul  \
# 0     Implementasi Fungsi Legislasi Dewan Perwakilan...
# 1     Pertanggungjawaban Pidana Direksi BUMN (Perser...
# 2     Analisis Terhadap Kekosongan Hukum dalam Penga...
# 3     PERLINDUNGAN HUKUM BAGI KONSUMEN ATAS PRODUK E...
# 4     TELAAH  KRITIS TENTANG ALASAN HUKUM YANG DIGUN...
# ...                                                 ...
# 2527             Meilinda Sari\n160321100007\nAgribinis
# 2528  Chilyatun Nafisah Oktavina\n160321100064\nAgri...
# 2529          I'ANATUS SHOFIYAH;160321100035;AGRIBISNIS
# 2530         Lilis Nur Azizah\n160321100038\nAgribisnis
# 2531     Farida\n18 juni 2020\n160321100052\nAgribisnis
#
#                                              abstrak_id  \
# 0     ABSTRAK\r\n\r\n       Implementasi Fungsi Legi...
# 1     Badan Usaha Milik Negara (BUMN) adalah Badan u...
# 2     Kasus narkoba tidak henti-hentinya terdengar d...
# 3     Produk elektronik adalah suatu benda bergerak ...
# 4
# ...                                                 ...
# 2527
# 2528
# 2529          I'ANATUS SHOFIYAH;160321100035;AGRIBISNIS
# 2530
# 2531
#
#                                              abstrak_en  \
# 0     ABSTRACT\r\n       Implementation of Legislati...
# 1     State Owned Enterprises (SOEs) are business en...
# 2     Drug cases endlessly heard on television, radi...
# 3     Electronic products is an object moves through...
# 4
# ...                                                 ...
# 2527
# 2528
# 2529          I'ANATUS SHOFIYAH;160321100035;AGRIBISNIS
# 2530
# 2531
#
#                    pembimbing_pertama                     pembimbing_kedua  \
# 0     Yudi Widagdo Harimurti, SH., MH                       Safi', SH., MH
# 1             Tolib Effendi, SH., MH.         Dr. Eni Suastuti, SH., Mhum.
# 2             Tolib Effendi, SH., MH.              Agus Ramdlany, SH., MH.
# 3           DR. DJULAEKA, S.H., M.HUM     DR.USWATUN HASANAH, S.H., M. HUM
# 4          Dr. DENI SBY, S. H., M. S.        SAIFUL ABDULLAH, S. H., M. H.
# ...                               ...                                  ...
# 2527  Novi Diana Badrut Tamami, SP.MP           Dr. Teti Sugiatri,SP.,M.Si
# 2528    Dr. Teti Sugiarti, SP., M.Si.          Dr. Elys Fauziyah, SP., MP.
# 2529    Dr. Teti Sugiarti, SP., M.Si.  Andrie K Sunyigono, SP., MP., Ph.D.
# 2530    Dr. Teti Sugiarti, S.P., M.Si       Dr. Mardiyah Hayati, S.P., M.P
# 2531       Dr. Elys Fauziyah, SP,. MP          Amanatuz Zuhriyah, SP,. MMA
#
#            prodi
# 0     Ilmu Hukum
# 1     Ilmu Hukum
# 2     Ilmu Hukum
# 3     Ilmu Hukum
# 4     Ilmu Hukum
# ...          ...
# 2527  Agribisnis
# 2528  Agribisnis
# 2529  Agribisnis
# 2530  Agribisnis
# 2531  Agribisnis
#
# [2532 rows x 8 columns]

# %% [markdown]
# ### Fungsi Crawling Data PTA (Dengan Batas Page)

# %%
def print_progress(prodi_id, prodi, current_page, total_pages):
    percent = (current_page / total_pages) * 100
    bar_length = 20
    filled_length = int(bar_length * current_page // total_pages)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    sys.stdout.write(f'\r[{prodi_id}] {prodi} - Page {current_page}/{total_pages} [{bar}] {percent:.2f}%')
    sys.stdout.flush()
    if current_page == total_pages:
        sys.stdout.write('\n\n')

def pta():
    start_time = time.time()  # mulai hitung waktu

    data = {
        "id": [],
        "penulis": [],
        "judul": [],
        "abstrak id": [],
        "abstrak en": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "prodi": [],
    }

    for i in range(1, 42):  # jumlah prodi
        total_pages = 15  # jumlah page
        prodi_name = None

        for j in range(1, total_pages + 1):  # loop page
            url = f"https://pta.trunojoyo.ac.id/c_search/byprod/{i}/{j}"
            r = requests.get(url)
            soup = BeautifulSoup(r.content, "html.parser")
            jurnals = soup.select('li[data-cat="#luxury"]')

            isii = soup.select_one('div#begin')
            if not isii:
                continue
            prodi_full = isii.select_one('h2').text.strip()
            prodi = prodi_full.replace("Journal Jurusan ", "")
            if not prodi_name:
                prodi_name = prodi

            for jurnal in jurnals:
                link = jurnal.select_one('a.gray.button')['href']

                # ambil ID dari link PTA
                id_match = re.search(r"/detail/(\d+)", link)
                pta_id = id_match.group(1) if id_match else None

                response = requests.get(link)
                soup1 = BeautifulSoup(response.content, "html.parser")
                isi = soup1.select_one('div#content_journal')

                # Judul
                judul = isi.select_one('a.title').text

                # Penulis
                penulis = isi.select_one('span:contains("Penulis")').text.split(' : ')[1]

                # Pembimbing Pertama
                pembimbing_pertama = isi.select_one('span:contains("Dosen Pembimbing I")').text.split(' : ')[1]

                # Pembimbing Kedua
                pembimbing_kedua = isi.select_one('span:contains("Dosen Pembimbing II")').text.split(' :')[1]

                # Abstrak
                paragraf = isi.select('p[align="justify"]')
                abstrak = paragraf[0].get_text(strip=True) if len(paragraf) > 0 else "N/A"
                abstract = paragraf[1].get_text(strip=True) if len(paragraf) > 1 else "N/A"

                # simpan data
                data["id"].append(pta_id)
                data["penulis"].append(penulis)
                data["judul"].append(judul)
                data["pembimbing_pertama"].append(pembimbing_pertama)
                data["pembimbing_kedua"].append(pembimbing_kedua)
                data["abstrak id"].append(abstrak)
                data["abstrak en"].append(abstract)
                data["prodi"].append(prodi)

            # update progress bar
            print_progress(i, prodi_name, j, total_pages)

    df = pd.DataFrame(data)
    df.to_csv("pta.csv", index=False, encoding="utf-8-sig")

    end_time = time.time()
    elapsed = int(end_time - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    # summary
    print("\n✅ Seluruh data berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱️ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

# %%
pta()
# Out:
# [1] Ilmu Hukum - Page 15/15 [████████████████████] 100.00%
#
# [2] Teknologi Industri Pertanian - Page 15/15 [████████████████████] 100.00%
#
# [3] Agribisnis - Page 15/15 [████████████████████] 100.00%
#
# [4] Agroteknologi - Page 15/15 [████████████████████] 100.00%
#
# [5] Ilmu Kelautan - Page 15/15 [████████████████████] 100.00%
#
# [6] Ekonomi Pembangunan - Page 15/15 [████████████████████] 100.00%
#
# [7] Manajemen - Page 15/15 [████████████████████] 100.00%
#
# [8] Akuntansi - Page 15/15 [████████████████████] 100.00%
#
# [9] Teknik Industri - Page 15/15 [████████████████████] 100.00%
#
# [10] Teknik Informatika - Page 15/15 [████████████████████] 100.00%
#
# [11] Manajemen Informatika - Page 15/15 [████████████████████] 100.00%
#
# [12] Sosiologi - Page 15/15 [████████████████████] 100.00%
#
# [13] Ilmu Komunikasi - Page 15/15 [████████████████████] 100.00%
#
# [14] Psikologi - Page 15/15 [████████████████████] 100.00%
#
# [15] Sastra Inggris - Page 15/15 [████████████████████] 100.00%
#
# [16] Ekonomi Syariah - Page 15/15 [████████████████████] 100.00%
#
# [17] Hukum Bisnis Syariah - Page 15/15 [████████████████████] 100.00%
#
# [18] Pgsd - Page 15/15 [████████████████████] 100.00%
#
# [19] Teknik Multimedia Dan Jaringan - Page 15/15 [████████████████████] 100.00%
#
# [20] Mekatronika - Page 15/15 [████████████████████] 100.00%
#
# [21] D3 Akuntansi - Page 15/15 [████████████████████] 100.00%
#
# [22] Magister Manajemen - Page 15/15 [████████████████████] 100.00%
#
# [23] Teknik Elektro - Page 15/15 [████████████████████] 100.00%
#
# [24] Magister Ilmu Hukum - Page 15/15 [████████████████████] 100.00%
#
# [25] Magister Akuntansi - Page 15/15 [████████████████████] 100.00%
#
# [26] D3 Enterpreneurship - Page 15/15 [████████████████████] 100.00%
#
# [27] Pendidikan Bhs Dan Sastra Indonesia - Page 15/15 [████████████████████] 100.00%
#
# [28] Pendidikan Informatika - Page 15/15 [████████████████████] 100.00%
#
# [29] Pendidikan Ipa - Page 15/15 [████████████████████] 100.00%
#
# [30] Pgpaud - Page 15/15 [████████████████████] 100.00%
#
# [31] Sistem Informasi - Page 15/15 [████████████████████] 100.00%
#
# [32] Teknik Mesin - Page 15/15 [████████████████████] 100.00%
#
# [33] Teknik Mekatronika - Page 15/15 [████████████████████] 100.00%
#
# [34] Journal Jurusan - Page 15/15 [████████████████████] 100.00%
#
# [35] Manajemen Sumberdaya Perairan - Page 15/15 [████████████████████] 100.00%
#
# [36] Magister Ilmu Ekonomi - Page 15/15 [████████████████████] 100.00%
#
# [37] Magister Pengelolaan Sumber Daya Alam - Page 15/15 [████████████████████] 100.00%
#
# [38] Pendidikan Profesi Guru - Page 15/15 [████████████████████] 100.00%
#
# [39] Magister Pendidikan Dasar - Page 15/15 [████████████████████] 100.00%
#
# [40] Doktor Pengelolaan Sumber Daya Alam - Page 15/15 [████████████████████] 100.00%
#
# [41] Doktor Ilmu Manajemen - Page 15/15 [████████████████████] 100.00%
#
#
# ✅ Seluruh data berhasil dikumpulkan!
# 📊 Total entri: 2266
# ⏱️ Waktu eksekusi: 1 jam 35 menit 11 detik
#                 id                           penulis  \
# 0     080111100012               Dyah Ayu Citra Seza
# 1     080111100002                  Maulina Nurlaily
# 2     070111100060               Moh. Samsul Hidayat
# 3     090111100077  TOMMY ADITYA PARLINDUNGAN MARBUN
# 4     070111200007                RICA YENA IMADHORA
# ...            ...                               ...
# 2261  160281100013   Lisa Sri rahmatullah, S. Sos. I
# 2262  160281100002                Indah Ainun Nikmah
# 2263  170361100010                ahmad syaiful umam
# 2264  170361100001                      Siti Holifah
# 2265  170361100003                   Mohammad Maskur
#
#                                                   judul  \
# 0     Implementasi Fungsi Legislasi Dewan Perwakilan...
# 1     Pertanggungjawaban Pidana Direksi BUMN (Perser...
# 2     Analisis Terhadap Kekosongan Hukum dalam Penga...
# 3     PERLINDUNGAN HUKUM BAGI KONSUMEN ATAS PRODUK E...
# 4     TELAAH  KRITIS TENTANG ALASAN HUKUM YANG DIGUN...
# ...                                                 ...
# 2261  Dampak Sosial Ekonomi Pariwisata Religi Makam ...
# 2262  Peranan Zakat Produktif Dalam Meningkatkan Eko...
# 2263  KARAKTERISASI DAN KOLEKSI PLASMA NUTFAH UNTUK ...
# 2264  PENGOLAHAN LIMBAH AIR REBUSAN IKAN TERI MENJAD...
# 2265  STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS...
#
#                                              abstrak id  \
# 0     ABSTRAK\r\n\r\n       Implementasi Fungsi Legi...
# 1     Badan Usaha Milik Negara (BUMN) adalah Badan u...
# 2     Kasus narkoba tidak henti-hentinya terdengar d...
# 3     Produk elektronik adalah suatu benda bergerak ...
# 4
# ...                                                 ...
# 2261  Penelitian ini bertujuan untuk mengetahui baga...
# 2262  Peranan Zakat Produktif dalam Meningkatkan Eko...
# 2263  Madura merupakan salah satu wilayah pemasok ko...
# 2264  Ikan Teri perlu penanganan serius pasca panen ...
# 2265  Makanan dan minuman khas merupakan ciri dari k...
#
#                                              abstrak en  \
# 0     ABSTRACT\r\n       Implementation of Legislati...
# 1     State Owned Enterprises (SOEs) are business en...
# 2     Drug cases endlessly heard on television, radi...
# 3     Electronic products is an object moves through...
# 4
# ...                                                 ...
# 2261  The purpose of this study is to analyze the so...
# 2262  The Role of Productive Zakat in Improving Must...
# 2263  Madura is one of the regions supplying horticu...
# 2264  Anchovy needs serious handling after harvest b...
# 2265  Typical food and drinks are characteristic of ...
#
#                       pembimbing_pertama  \
# 0        Yudi Widagdo Harimurti, SH., MH
# 1                Tolib Effendi, SH., MH.
# 2                Tolib Effendi, SH., MH.
# 3              DR. DJULAEKA, S.H., M.HUM
# 4             Dr. DENI SBY, S. H., M. S.
# ...                                  ...
# 2261  Dr. Diah Wahyuningsih, S.E., M.Si.
# 2262       Dr. Kurniyati Indahsari, M.Si
# 2263           Dr. Ir. Gita Pawana, M.Si
# 2264        Dr.Apri Arisandi,S.Pi.,M.Si.
# 2265         Dr. Akhmad Farid, S.Pi., MT
#
#                            pembimbing_kedua  \
# 0                            Safi', SH., MH
# 1              Dr. Eni Suastuti, SH., Mhum.
# 2                   Agus Ramdlany, SH., MH.
# 3          DR.USWATUN HASANAH, S.H., M. HUM
# 4             SAIFUL ABDULLAH, S. H., M. H.
# ...                                     ...
# 2261  Dr. Eni Sri Rahayuningsih, S.E., M.E.
# 2262            Dr. Abdur Rahman, S.Ag. MEI
# 2263         Dr. Ir. Hj. SIti Fatimah, M.Si
# 2264                      Dr.Ir.H.Asfan,MP.
# 2265         Dr. Apri Arisandi, S.Pi., M.Si
#
#                                       prodi
# 0                                Ilmu Hukum
# 1                                Ilmu Hukum
# 2                                Ilmu Hukum
# 3                                Ilmu Hukum
# 4                                Ilmu Hukum
# ...                                     ...
# 2261                  Magister Ilmu Ekonomi
# 2262                  Magister Ilmu Ekonomi
# 2263  Magister Pengelolaan Sumber Daya Alam
# 2264  Magister Pengelolaan Sumber Daya Alam
# 2265  Magister Pengelolaan Sumber Daya Alam
#
# [2266 rows x 8 columns]

# %% [markdown]
# ## Page & Link Keluar PTA

# %%
def print_progress(prodi_id, prodi, current_page, total_pages):
    percent = (current_page / total_pages) * 100
    bar_length = 20
    filled_length = int(bar_length * current_page // total_pages)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    sys.stdout.write(f'\r[{prodi_id}] {prodi} - Page {current_page}/{total_pages} [{bar}] {percent:.2f}%')
    sys.stdout.flush()
    if current_page == total_pages:
        sys.stdout.write('\n\n')

def pta_links():
    start_time = time.time()  # mulai hitung waktu

    data = {
        "no": [],
        "page": [],
        "link_keluar": []
    }

    no = 1  # nomor urut

    for i in range(1, 10):  # jumlah prodi
        total_pages = 15  # jumlah page
        prodi_name = None

        for j in range(1, total_pages + 1):  # loop page
            url = f"https://pta.trunojoyo.ac.id/c_search/byprod/{i}/{j}"
            r = requests.get(url)
            soup = BeautifulSoup(r.content, "html.parser")
            jurnals = soup.select('li[data-cat="#luxury"]')

            isii = soup.select_one('div#begin')
            if not isii:
                continue
            prodi_full = isii.select_one('h2').text.strip()
            prodi = prodi_full.replace("Journal Jurusan ", "")
            if not prodi_name:
                prodi_name = prodi

            for jurnal in jurnals:
                link = jurnal.select_one('a.gray.button')['href']

                data["no"].append(no)
                data["page"].append(url)          # link page
                data["link_keluar"].append(link)  # link detail
                no += 1

            # update progress bar
            print_progress(i, prodi_name, j, total_pages)

    df = pd.DataFrame(data)
    df.to_csv("pta_links.csv", index=False)

    end_time = time.time()
    elapsed = int(end_time - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    # summary
    print("\n✅ Seluruh link berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱️ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

# %%
pta_links()
# Out:
# [1] Ilmu Hukum - Page 15/15 [████████████████████] 100.00%
#
# [2] Teknologi Industri Pertanian - Page 15/15 [████████████████████] 100.00%
#
# [3] Agribisnis - Page 15/15 [████████████████████] 100.00%
#
# [4] Agroteknologi - Page 15/15 [████████████████████] 100.00%
#
# [5] Ilmu Kelautan - Page 15/15 [████████████████████] 100.00%
#
# [6] Ekonomi Pembangunan - Page 15/15 [████████████████████] 100.00%
#
# [7] Manajemen - Page 15/15 [████████████████████] 100.00%
#
# [8] Akuntansi - Page 15/15 [████████████████████] 100.00%
#
# [9] Teknik Industri - Page 15/15 [████████████████████] 100.00%
#
#
# ✅ Seluruh link berhasil dikumpulkan!
# 📊 Total entri: 675
# ⏱️ Waktu eksekusi: 0 jam 10 menit 52 detik
#       no                                              page  \
# 0      1   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 1      2   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 2      3   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 3      4   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 4      5   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# ..   ...                                               ...
# 670  671  https://pta.trunojoyo.ac.id/c_search/byprod/9/15
# 671  672  https://pta.trunojoyo.ac.id/c_search/byprod/9/15
# 672  673  https://pta.trunojoyo.ac.id/c_search/byprod/9/15
# 673  674  https://pta.trunojoyo.ac.id/c_search/byprod/9/15
# 674  675  https://pta.trunojoyo.ac.id/c_search/byprod/9/15
#
#                                            link_keluar
# 0    https://pta.trunojoyo.ac.id/welcome/detail/080...
# 1    https://pta.trunojoyo.ac.id/welcome/detail/080...
# 2    https://pta.trunojoyo.ac.id/welcome/detail/070...
# 3    https://pta.trunojoyo.ac.id/welcome/detail/090...
# 4    https://pta.trunojoyo.ac.id/welcome/detail/070...
# ..                                                 ...
# 670  https://pta.trunojoyo.ac.id/welcome/detail/080...
# 671  https://pta.trunojoyo.ac.id/welcome/detail/080...
# 672  https://pta.trunojoyo.ac.id/welcome/detail/060...
# 673  https://pta.trunojoyo.ac.id/welcome/detail/080...
# 674  https://pta.trunojoyo.ac.id/welcome/detail/080...
#
# [675 rows x 3 columns]

# %% [markdown]
# ## 2. Crawling Berita

# %% [markdown]
# ### Fungsi

# %%
# Fungsi progress bar manual
def print_progress(kategori, current_page, total_pages):
    percent = (current_page / total_pages) * 100
    bar_length = 20
    filled_length = int(bar_length * current_page // total_pages)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    sys.stdout.write(f'\r{kategori} - Page {current_page}/{total_pages} [{bar}] {percent:.2f}%')
    sys.stdout.flush()
    if current_page == total_pages:
        sys.stdout.write('\n\n')

# %%
# Fungsi untuk ambil konten artikel
def get_article_content(url):
    r = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    soup = BeautifulSoup(r.text, "html.parser")

    paragraphs = []
    content_divs = soup.find_all("div", id="content-wrapper")
    for div in content_divs:
        for p in div.find_all("p"):
            text = p.get_text(strip=True)
            if text and not text.lower().startswith("baca juga"):
                paragraphs.append(text)
    return " ".join(paragraphs)

# %% [markdown]
# ### Fungsi Crawling Berita

# %%
def berita(categories, pages_per_category=1):
    start_time = time.time()  # mulai hitung waktu

    BASE_URL = "https://www.tempo.co/indeks?page={}&category=rubrik&rubric_slug={}"

    data = {
        "id_berita": [],
        "judul_berita": [],
        "isi_berita": [],
        "kategori_berita": []
    }

    for cat_id, cat in enumerate(categories, start=1):
        for page in range(1, pages_per_category+1):
            url = BASE_URL.format(page, cat)
            r = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
            soup = BeautifulSoup(r.text, "html.parser")

            articles = soup.select("figure figcaption a")
            for a in articles:
                link = "https://www.tempo.co" + a["href"]
                title = a.get_text(strip=True)

                id_match = re.search(r"-(\d+)$", link)
                berita_id = id_match.group(1) if id_match else None

                try:
                    content = get_article_content(link)
                except:
                    content = ""

                data["id_berita"].append(berita_id)
                data["judul_berita"].append(title)
                data["isi_berita"].append(content)
                data["kategori_berita"].append(cat)

            print_progress(cat, page, pages_per_category)

    df = pd.DataFrame(data)
    df.to_csv("tempo_berita.csv", index=False, encoding="utf-8-sig")

    end_time = time.time()
    elapsed = int(end_time - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    # summary
    print("\n✅ Seluruh data berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱️ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

categories = ["politik", "hukum", "ekonomi", "hiburan", "internasional", "otomotif", "olahraga"]

# %%
berita(categories, pages_per_category=5)
# Out:
# politik - Page 5/5 [████████████████████] 100.00%
#
# hukum - Page 5/5 [████████████████████] 100.00%
#
# ekonomi - Page 5/5 [████████████████████] 100.00%
#
# hiburan - Page 5/5 [████████████████████] 100.00%
#
# internasional - Page 5/5 [████████████████████] 100.00%
#
# otomotif - Page 5/5 [████████████████████] 100.00%
#
# olahraga - Page 5/5 [████████████████████] 100.00%
#
#
# ✅ Seluruh data berhasil dikumpulkan!
# 📊 Total entri: 700
# ⏱️ Waktu eksekusi: 0 jam 0 menit 51 detik
#     id_berita                                       judul_berita isi_berita  \
# 0     2068663      Kronologi Mundurnya Rahayu Saraswati dari DPR
# 1     2068660          Kata Wapres Gibran soal Reshuffle Kabinet
# 2     2068655  Kata Staf Khusus Gubernur Jakarta soal Tanggul...
# 3     2068650  Empat Nama Mencuat dalam Bursa Calon Sekda Kab...
# 4     2068644  Top 3 Nasional: Klarifikasi Purbaya hingga Rah...
# ..        ...                                                ...        ...
# 695   2063170  Carlos Alcaraz Berharap Bertemu Sinner di Fina...
# 696   2063140  Perjalanan Janice Tjen yang Mencetak Sejarah d...
# 697   2063016  Jadwal Kejuaraan Dunia Bulu Tangkis 2025: 8 Wa...
# 698   2062822  Profil Janice Tjen, Petenis Indonesia yang Tem...
# 699   2062845  Janice Tjen Sempat Ragu Melanjutkan Karier seb...
#
#     kategori_berita
# 0           politik
# 1           politik
# 2           politik
# 3           politik
# 4           politik
# ..              ...
# 695        olahraga
# 696        olahraga
# 697        olahraga
# 698        olahraga
# 699        olahraga
#
# [700 rows x 4 columns]

# %% [markdown]
# ## Page & Link Keluar Berita

# %%
def berita_links(categories, pages_per_category=1):
    start_time = time.time()  # mulai hitung waktu

    BASE_URL = "https://www.tempo.co/indeks?page={}&category=rubrik&rubric_slug={}"

    data = {
        "id_berita": [],
        "page": [],
        "link_keluar": []
    }

    for cat in categories:
        for page in range(1, pages_per_category+1):
            url = BASE_URL.format(page, cat)
            r = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
            soup = BeautifulSoup(r.text, "html.parser")

            articles = soup.select("figure figcaption a")
            for a in articles:
                link = "https://www.tempo.co" + a["href"]
                id_match = re.search(r"-(\d+)$", link)
                berita_id = id_match.group(1) if id_match else None

                data["id_berita"].append(berita_id)
                data["page"].append(url)         # link page
                data["link_keluar"].append(link) # link detail

            # update progress bar
            print_progress(cat, page, pages_per_category)

    df = pd.DataFrame(data)
    df.to_csv("tempo_links.csv", index=False, encoding="utf-8-sig")

    end_time = time.time()
    elapsed = int(end_time - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    # summary
    print("\n✅ Seluruh link berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱️ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

categories = ["politik", "hukum", "ekonomi", "hiburan", "internasional", "otomotif", "olahraga"]

# %%
berita_links(categories, pages_per_category=5)
# Out:
# politik - Page 5/5 [████████████████████] 100.00%
#
# hukum - Page 5/5 [████████████████████] 100.00%
#
# ekonomi - Page 5/5 [████████████████████] 100.00%
#
# hiburan - Page 5/5 [████████████████████] 100.00%
#
# internasional - Page 5/5 [████████████████████] 100.00%
#
# otomotif - Page 5/5 [████████████████████] 100.00%
#
# olahraga - Page 5/5 [████████████████████] 100.00%
#
#
# ✅ Seluruh link berhasil dikumpulkan!
# 📊 Total entri: 700
# ⏱️ Waktu eksekusi: 0 jam 0 menit 40 detik
#     id_berita                                               page  \
# 0     2068663  https://www.tempo.co/indeks?page=1&category=ru...
# 1     2068660  https://www.tempo.co/indeks?page=1&category=ru...
# 2     2068655  https://www.tempo.co/indeks?page=1&category=ru...
# 3     2068650  https://www.tempo.co/indeks?page=1&category=ru...
# 4     2068644  https://www.tempo.co/indeks?page=1&category=ru...
# ..        ...                                                ...
# 695   2063170  https://www.tempo.co/indeks?page=5&category=ru...
# 696   2063140  https://www.tempo.co/indeks?page=5&category=ru...
# 697   2063016  https://www.tempo.co/indeks?page=5&category=ru...
# 698   2062822  https://www.tempo.co/indeks?page=5&category=ru...
# 699   2062845  https://www.tempo.co/indeks?page=5&category=ru...
#
#                                            link_keluar
# 0    https://www.tempo.co/politik/kronologi-mundurn...
# 1    https://www.tempo.co/politik/kata-wapres-gibra...
# 2    https://www.tempo.co/politik/kata-staf-khusus-...
# 3    https://www.tempo.co/politik/empat-nama-mencua...
# 4    https://www.tempo.co/politik/top-3-nasional-kl...
# ..                                                 ...
# 695  https://www.tempo.co/olahraga/carlos-alcaraz-b...
# 696  https://www.tempo.co/olahraga/perjalanan-janic...
# 697  https://www.tempo.co/olahraga/jadwal-kejuaraan...
# 698  https://www.tempo.co/olahraga/profil-janice-tj...
# 699  https://www.tempo.co/olahraga/janice-tjen-semp...
#
# [700 rows x 3 columns]
